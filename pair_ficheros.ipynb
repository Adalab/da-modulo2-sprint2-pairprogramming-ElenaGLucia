# %%
pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#      ---------------------------------------- 0.0/250.0 kB ? eta -:--:--
#      - -------------------------------------- 10.2/250.0 kB ? eta -:--:--
#      ------ ------------------------------ 41.0/250.0 kB 330.3 kB/s eta 0:00:01
#      ---------------- ------------------- 112.6/250.0 kB 819.2 kB/s eta 0:00:01
#      ----------------------------- -------- 194.6/250.0 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------- 250.0/250.0 kB 1.2 MB/s eta 0:00:00
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: C:\Users\elmgu\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# Importar librerías para manipulación y análisis de datos
# -----------------------------------------------------------------------
import pandas as pd

# Importar openpyxl para manipular excels
# -----------------------------------------------------------------------
import openpyxl

# %% [markdown]
# ##### 1. Hacer las importaciones necesarias para abrir un archivo de tipo "csv" en Pandas

# %%
juegos = pd.read_csv("videogames.csv")

# %% [markdown]
# ##### 2. Abrir el archivo, creando un Dataframe. Aseguraros de que no incluye la columna "Unnamed: 0"

# %%
juegos = pd.read_csv("videogames.csv", index_col = 0)

# %% [markdown]
# #### 3. Una vez creado el Dataframe, muestra las 10 primeras filas

# %%
juegos.head(10)
# Out:
#                          name  \
# 0                  Spider-Man
# 1      Red Dead Redemption II
# 2          Grand Theft Auto V
# 3                  God of War
# 4  Uncharted 4: A Thief's End
# 5     The Last of Us: Part II
# 6      Horizon Forbidden West
# 7              The Last of Us
# 8       Detroit: Become Human
# 9             Death Stranding
#
#                                                  url    year certificate  \
# 0  https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1  https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2  https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3  https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# 4  https://www.imdb.com/title/tt3334704/?ref_=adv...  2016.0           T
# 5  https://www.imdb.com/title/tt6298000/?ref_=adv...  2020.0           M
# 6  https://www.imdb.com/title/tt12496904/?ref_=ad...  2022.0           T
# 7  https://www.imdb.com/title/tt2140553/?ref_=adv...  2013.0           M
# 8  https://www.imdb.com/title/tt5158314/?ref_=adv...  2018.0           M
# 9  https://www.imdb.com/title/tt5807606/?ref_=adv...  2019.0           M
#
#    rating   votes                                               plot  Action  \
# 0     9.2  20,759  When a new villain threatens New York City, Pe...    True
# 1     9.7  35,703  Amidst the decline of the Wild West at the tur...    True
# 2     9.5  59,986  Three very different criminals team up for a s...    True
# 3     9.6  26,118  After wiping out the gods of Mount Olympus, Kr...    True
# 4     9.5  28,722  Thrown back into the dangerous underworld he'd...    True
# 5     8.5  30,460  Five years after the events of The Last of Us,...    True
# 6     9.2   2,979  Aloy treks into an arcane region and faces new...    True
# 7     9.7  60,590  In a hostile, post-pandemic world, Joel and El...    True
# 8     9.2  16,907  Take control of three androids in their quest ...    True
# 9     8.8   8,136  Deliveryman Sam Porter must travel across a ra...    True
#
#    Adventure  Comedy  Crime  Family  Fantasy  Mystery  Sci-Fi  Thriller
# 0       True   False  False   False     True    False   False     False
# 1       True   False   True   False    False    False   False     False
# 2      False   False   True   False    False    False   False     False
# 3       True   False  False   False    False    False   False     False
# 4       True   False  False   False    False    False   False     False
# 5       True   False  False   False    False    False   False     False
# 6       True   False  False   False    False     True   False     False
# 7       True   False  False   False    False    False   False     False
# 8       True   False  False   False    False    False   False     False
# 9       True   False  False   False    False    False   False     False

# %% [markdown]
# ##### 4. ¿Cúal es el último índice que tenemos en el Dataframe?

# %%
juegos.tail(1)
# Out:
#           name                                                url    year  \
# 20802  Cryptic  https://www.imdb.com/title/tt10964974/?ref_=ad...  2020.0
#
#       certificate  rating votes  \
# 20802         NaN     NaN   NaN
#
#                                                     plot  Action  Adventure  \
# 20802  Kidnapped by an insane man and dragged into a ...   False      False
#
#        Comedy  Crime  Family  Fantasy  Mystery  Sci-Fi  Thriller
# 20802   False  False   False    False    False   False      True

# %% [markdown]
# ##### 5. Mostrar 15 filas aleatorias

# %%
juegos.sample(15)
# Out:
#                                                    name  \
# 16512                                       Hopper Robo
# 20607                            Alien Breed: Evolution
# 19399                                          TRON 2.0
# 14837                                      For the Game
# 15720                                   Virtual Juggler
# 8399                                   .38 Ambush Alley
# 3801                   TV Animation X: Unmei No Tatakai
# 3054                                          Galerians
# 11569  The Legend of the Mystical Ninja Starring Goemon
# 7766                                   Bio F.R.E.A.K.S.
# 308                                           Half-Life
# 18227                                       Last Period
# 10395                                 Stick War: Legacy
# 1584                                            Spyjinx
# 3461                                    1080: Avalanche
#
#                                                      url    year certificate  \
# 16512  https://www.imdb.com/title/tt2229209/?ref_=adv...  1983.0         NaN
# 20607  https://www.imdb.com/title/tt4789720/?ref_=adv...  2009.0         NaN
# 19399  https://www.imdb.com/title/tt0208650/?ref_=adv...  2003.0         NaN
# 14837  https://www.imdb.com/title/tt1094173/?ref_=adv...  2009.0         NaN
# 15720  https://www.imdb.com/title/tt0954985/?ref_=adv...  2004.0     Unrated
# 8399   https://www.imdb.com/title/tt0370236/?ref_=adv...  1987.0         NaN
# 3801   https://www.imdb.com/title/tt3877156/?ref_=adv...  2002.0         NaN
# 3054   https://www.imdb.com/title/tt0260918/?ref_=adv...  1999.0           M
# 11569  https://www.imdb.com/title/tt0285673/?ref_=adv...  1998.0           E
# 7766   https://www.imdb.com/title/tt5450952/?ref_=adv...  1998.0           M
# 308    https://www.imdb.com/title/tt0239023/?ref_=adv...  1998.0           M
# 18227  https://www.imdb.com/title/tt5619276/?ref_=adv...  2016.0         NaN
# 10395  https://www.imdb.com/title/tt9040692/?ref_=adv...  2015.0         NaN
# 1584   https://www.imdb.com/title/tt8434496/?ref_=adv...  2019.0         NaN
# 3461   https://www.imdb.com/title/tt0363396/?ref_=adv...  2003.0           E
#
#        rating   votes                                               plot  \
# 16512     NaN     NaN                                         Add a Plot
# 20607     NaN     NaN  Survival Action Horror game that is a reboot o...
# 19399     8.3     292  When Encom programmer Alan Bradley goes missin...
# 14837     NaN     NaN                                         Add a Plot
# 15720     8.2      17                                         Add a Plot
# 8399      NaN     NaN  You are at a police academy shooting cardboard...
# 3801      7.4       6  A air-based fighting game based on the Anime r...
# 3054      8.0      56  The Galerians want to destroy the human race. ...
# 11569     8.2      77                                         Add a Plot
# 7766      5.5      63  Bio F.R.E.A.K.S. (Flying Robotic Enhanced Armo...
# 308       9.2  10,164  Dr. Gordon Freeman must fight his way out of a...
# 18227     5.9       9                                         Add a Plot
# 10395     7.8      15  In this game, you battle against many kingdoms...
# 1584      3.0      25  SPYJINX is a unique mix of action strategy gam...
# 3461      6.9      57  The player can choose their character to go sn...
#
#        Action  Adventure  Comedy  Crime  Family  Fantasy  Mystery  Sci-Fi  \
# 16512   False      False   False  False    True    False    False    True
# 20607    True      False   False  False   False    False    False    True
# 19399    True       True   False  False   False    False    False    True
# 14837    True       True   False  False   False     True    False   False
# 15720   False      False    True  False   False    False    False   False
# 8399     True      False   False  False   False    False    False   False
# 3801     True      False   False  False   False     True    False   False
# 3054     True       True   False  False   False     True    False   False
# 11569   False       True    True  False    True    False    False   False
# 7766     True      False   False  False   False    False    False    True
# 308      True      False   False  False   False    False    False    True
# 18227   False      False   False  False   False     True    False   False
# 10395   False       True   False  False   False    False    False   False
# 1584     True      False   False  False   False    False    False   False
# 3461     True      False   False  False   False    False    False   False
#
#        Thriller
# 16512     False
# 20607     False
# 19399     False
# 14837     False
# 15720     False
# 8399      False
# 3801      False
# 3054      False
# 11569     False
# 7766      False
# 308        True
# 18227     False
# 10395     False
# 1584      False
# 3461      False

# %% [markdown]
# ##### 6. Crea una lista con el nombre de las columnas

# %%
juegos.columns
# Out:
# Index(['name', 'url', 'year', 'certificate', 'rating', 'votes', 'plot',
#        'Action', 'Adventure', 'Comedy', 'Crime', 'Family', 'Fantasy',
#        'Mystery', 'Sci-Fi', 'Thriller'],
#       dtype='object')

# %% [markdown]
# ##### 7. Guardar el Dataframe en formato Excel y después crear un Dataframe con el Excel. ¿EL Dataframe es similar al que teníais antes?

# %%
juegos.to_excel("jueguitos.xlsx")

# %% [markdown]
# ##### 8. Muestra la "info" del Dataframe

# %%
jueguitos = pd.read_excel("jueguitos.xlsx", index_col = 0)

# %%
jueguitos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20803 entries, 0 to 20802
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         20803 non-null  object
#  1   url          20803 non-null  object
#  2   year         20536 non-null  float64
#  3   certificate  7903 non-null   object
#  4   rating       11600 non-null  float64
#  5   votes        11600 non-null  object
#  6   plot         20803 non-null  object
#  7   Action       20803 non-null  bool
#  8   Adventure    20803 non-null  bool
#  9   Comedy       20803 non-null  bool
#  10  Crime        20803 non-null  bool
#  11  Family       20803 non-null  bool
#  12  Fantasy      20803 non-null  bool
#  13  Mystery      20803 non-null  bool
#  14  Sci-Fi       20803 non-null  bool
#  15  Thriller     20803 non-null  bool
# dtypes: bool(9), float64(2), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# ##### 9. ¿Tiene nulos o duplicados?

# %%
jueguitos.isnull().sum()
# Out:
# name               0
# url                0
# year             267
# certificate    12900
# rating          9203
# votes           9203
# plot               0
# Action             0
# Adventure          0
# Comedy             0
# Crime              0
# Family             0
# Fantasy            0
# Mystery            0
# Sci-Fi             0
# Thriller           0
# dtype: int64

# %% [markdown]
# ##### 10. Obtener la descripción del Dataframe, tanto de las columnas numéricas como de las de tipo "object". Explorar el resultado y sacar unas mínimas comclusiones sobre los datos que habéis obtenido

# %%
jueguitos.describe(include="object") #Info de las columnas categóricas
# Out:
#               name                                                url  \
# count        20803                                              20803
# unique       19714                                              20157
# top     Spider-Man  https://www.imdb.com/title/tt5807780/?ref_=adv...
# freq             9                                                  4
#
#        certificate  votes        plot
# count         7903  11600       20803
# unique          21   1905       11276
# top              T      7  Add a Plot
# freq          2474    318        8874

# %%
jueguitos.describe() #Info de las columnas numéricas
# Out:
#                year        rating
# count  20536.000000  11600.000000
# mean    2005.568611      7.047526
# std       11.846028      1.235204
# min     1952.000000      1.000000
# 25%     1997.000000      6.400000
# 50%     2008.000000      7.200000
# 75%     2016.000000      7.900000
# max     2027.000000      9.700000

# %% [markdown]
# ##### 11. Finalmente, guarda el Dataframe en formato "csv" con un nombre diferente del original

# %%
jueguitos.to_csv("juegos.csv")
